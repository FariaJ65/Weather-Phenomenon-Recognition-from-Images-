# %%
from google.colab import drive
drive.mount("/content/drive" ,force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install opencv-contrib-python==4.4.0.44
# Out:
# Collecting opencv-contrib-python==4.4.0.44
#   Downloading opencv_contrib_python-4.4.0.44-cp37-cp37m-manylinux2014_x86_64.whl (55.7 MB)
#      |████████████████████████████████| 55.7 MB 272 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python==4.4.0.44) (1.19.5)
# Installing collected packages: opencv-contrib-python
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
# Successfully installed opencv-contrib-python-4.4.0.44

# %%
import os
import os.path
import imutils
import cv2
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import math
import argparse
import glob
from tqdm import tqdm

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte

# %%
cv2.__version__
# Out:
# '4.4.0'

# %%
# for weather_dataset(11 class) ,weather_dataset2(4 class)

# %%
#TRAIN="/content/drive/MyDrive/Thesis/weather_dataset_4"
TRAIN="/content/drive/MyDrive/Thesis/weather_dataset_11"

# %%
CLASS = ["dew", "fogsmog" ,"frost","glaze","hail","lightning","rain","rainbow","rime","sandstorm","snow"]
#CLASS = ["cloudy","rain","shine","sunrise"]

# %%
train_data= []

# %%
for category in CLASS:
  path = os.path.join(TRAIN,category)  # create path to weather class
  train_labels = CLASS.index(category)
  for img in os.listdir(path):  # iterate over each image per class    
    train_img = os.path.join(path,img)# target_size =(100,100))# resize
    train_data.append(train_img)

# %%
train_data
# Out:
# ['/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (32).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (15).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (21).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (63).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (5).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (41).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (10).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (87).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (65).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (9).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (70).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (118).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (54).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (16).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (52).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (121).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (17).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (76).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (11).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (28).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (3).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (61).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (39).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (74).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (34).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (26).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (120).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (93).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (73).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (96).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (84).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (72).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (125).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (31).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (69).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (89).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (100).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (102).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (27).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (64).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (79).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (116).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (78).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (110).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (94).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (50).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (92).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (1).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (99).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (119).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (48).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (115).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (2).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (90).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (36).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (43).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (4).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (49).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (86).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (107).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (122).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (95).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (33).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (42).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (13).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (113).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (103).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (60).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (47).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (126).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (59).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (14).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (58).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (45).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (109).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (111).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (7).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (106).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (124).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (71).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (55).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (77).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (30).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (37).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (53).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (62).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (57).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (67).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (75).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (91).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (8).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (44).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (97).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (24).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (38).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (29).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (85).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (123).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (25).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (46).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (104).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (108).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (66).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (101).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (82).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (20).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (19).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (68).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (18).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (114).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (81).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (83).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (40).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (23).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (51).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (12).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (88).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (22).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (112).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (35).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (6).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (56).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (117).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (105).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (80).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (98).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (212).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (184).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (224).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (200).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (223).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (203).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (182).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (161).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (142).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (188).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (131).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (204).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (129).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (246).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (174).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (149).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (213).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (177).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (249).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (218).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (193).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (250).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (164).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (154).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (201).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (145).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (244).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (242).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (197).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (239).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (230).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (209).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (189).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (176).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (139).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (168).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (222).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (231).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (198).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (194).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (133).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (191).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (150).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (159).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (235).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (143).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (210).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (245).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (163).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (173).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (207).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (237).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (137).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (221).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (236).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (146).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (141).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (243).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (215).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (185).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (208).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (148).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (152).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (162).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (228).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (130).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (227).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (136).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (181).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (217).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (138).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (155).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (233).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (144).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (140).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (169).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (134).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (135).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (165).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (202).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (172).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (186).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (132).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (180).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (192).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (156).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (225).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (216).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (220).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (226).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (248).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (229).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (153).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (167).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (219).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (234).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (170).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (158).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (205).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (160).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (247).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (196).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (128).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (151).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (178).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (199).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (195).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (238).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (240).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (147).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (157).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (206).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (214).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (183).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (241).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (232).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (166).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (190).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (127).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (179).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (171).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (187).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (175).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (211).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (269).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (322).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (280).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (316).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (332).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (306).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (308).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (305).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (336).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (317).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (294).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (338).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (347).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (359).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (304).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (303).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (352).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (275).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (349).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (291).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (287).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (251).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (366).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (319).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew (311).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/dew/dew
jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (683).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (615).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (852).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (833).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (692).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (556).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (748).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (579).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (780).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (604).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (699).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (695).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (768).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (572).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (666).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (765).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (835).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (821).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (616).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (678).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (637).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (742).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (795).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (707).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (575).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (698).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (605).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (732).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (754).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (816).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (727).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (706).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (740).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (811).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (596).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (651).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (854).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (752).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (689).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (576).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (843).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (773).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (645).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (844).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (829).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (700).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (668).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (639).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (814).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (798).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (696).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (738).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (779).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (726).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (603).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (702).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (801).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (646).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (750).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (669).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (686).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (656).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (662).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (691).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (659).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (758).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (716).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (629).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (760).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (552).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (590).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (851).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (635).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (592).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (817).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (573).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (680).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (853).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (697).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (676).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (564).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (571).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (622).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (648).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (786).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (611).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (848).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (728).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (612).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (783).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (753).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (799).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (555).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (557).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (756).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (623).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (690).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (787).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (837).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (675).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (812).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (562).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (729).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (784).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (794).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (570).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (548).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (633).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (599).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (563).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (831).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (649).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (790).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (820).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (839).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (625).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (663).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (701).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (715).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (743).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (665).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (607).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (626).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (749).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (744).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (577).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (610).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (713).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (736).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (636).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (606).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (731).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (600).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (776).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/fogsmog/fogsmog (840).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (6).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (22).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (1).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (16).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (5).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (3).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (14).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (18).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (12).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (20).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (11).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (13).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (4).jpg',
#  '/content/drive/MyDrive/Thesis/weather_dataset_11/frost/frost (2).jpg',
#  ...]

# %%
def CalcFeatures(img):
        feat = cv2.SIFT_create()
        #feat=cv2.xfeatures2d.SURF_create()
        kp, des = feat.detectAndCompute(img, None)
        return des

# %%
features = []
for file in train_data:
    img = cv2.imread(file)
    if type(img) is np.ndarray:
            if img.size == 0:
                continue
    if img is None:
      continue
    img_des = CalcFeatures(img)
features.append(img_des)
features = np.vstack(features)

# %%
len(features), img_des.shape
# Out:
# (4345, (4345, 128))

# %%
len(img_des)
# Out:
# 4345

# %%
k = 140
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 0.1)
flags = cv2.KMEANS_RANDOM_CENTERS
compactness, labels, centres = cv2.kmeans(np.float32(features), k, None, criteria, 10, flags)

# %%
def bag_of_features(features, centres, k = 500):
        vec = np.zeros((1, k))
        for i in range(features.shape[0]):
            feat = features[i]
            diff = np.tile(feat, (k, 1)) - centres
            dist = pow(((pow(diff, 2)).sum(axis = 1)), 0.5)
            idx_dist = dist.argsort()
            idx = idx_dist[0]
            vec[0][idx] += 1
        return vec

# %%
labels = []
vec = []
for file in train_data:
    img = cv2.imread(file, 0)
    if type(img) is np.ndarray:
            if img.size == 0:
                continue
    if img is None:
      continue
    img_des = CalcFeatures(img)
    if img_des is not None:
        img_vec = bag_of_features(img_des, centres, k)
        vec.append(img_vec)
        label = file.split("(")[0]  # 'label
        labels.append(label)   
vec = np.vstack(vec)

# %%
len(vec),len(labels)

# %%
X_train = vec 
y_train = labels

# %%
x_train, x_test, y_train, y_test = train_test_split(vec, labels, test_size=0.2,random_state=0, stratify = labels)

# %%
y_train

# %%
clf = SVC(kernel='linear')

clf.fit(x_train, y_train)

# %%
preds = clf.predict(x_test)

# %%
# printing the labels that are predicted
for pred2, lbl2 in zip(preds, y_test):
    print("\nResult:{} \nPrediction: {}\n".format(lbl2, pred2))

# %%
# printing the evaluations measures
print("\nAccuracy on test Set = \n", accuracy_score(y_test, preds))
print("\nClassification Report (test Set):\n")
cr = classification_report(y_test, preds, target_names=CLASS)
print(cr)

# %%
from sklearn.metrics import plot_confusion_matrix, ConfusionMatrixDisplay
l= np.array(CLASS)
type(l)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
fig, ax = plot_confusion_matrix(clf, x_test, y_test,ax=ax,  display_labels=l)

plt.show()
